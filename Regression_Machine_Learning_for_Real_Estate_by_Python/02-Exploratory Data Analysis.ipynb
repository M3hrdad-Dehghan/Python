# %% [markdown]
# ## 1. import packages and dataset

# %% [markdown]
# First, I should import necessary packages and also the cleaned dataset.

# %%
import pandas as pd
import numpy as np
import sweetviz as sv
import pickle

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline

# %%
with open('Dataset/df_preprocessed.pickle', 'rb') as file:
    df = pickle.load(file)

df.head(2)
# Out:
#                                   Type  Municipality  NearStation      Price  \
# 0  Residential Land(Land and Building)  Chiyoda Ward          2.0  400000000
# 1  Residential Land(Land and Building)  Chiyoda Ward          1.0  180000000
#
#   FloorPlan  Area           LandShape  Frontage  BuildingYear Structure  \
# 0        1K   110  Trapezoidal Shaped       9.0        2018.0         S
# 1        1K    50  Rectangular Shaped       5.2        1976.0        RC
#
#                Use  Direction Renovation
# 0           Office  Northwest    Not yet
# 1  Housing Complex  Southwest    Not yet

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2. Run SweetViz package

# %% [markdown]
# Then I activated the SweetViz library and prepared the environment for statistical analysis.  This library gives us all important information about descriptive statistics analysis.

# %%
analyze_report = sv.analyze(df)
analyze_report.show_html('Statistical_Analysis.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Statistical_Analysis.html was generated.

# %% [markdown]
# <hr>

# %% [markdown]
# ## 3. Qualitative Variables

# %% [markdown]
# Here we analyze qualitative variables, and we see each label in every single variable account for the highest frequency. Then, we can see the statistical interpretation for categorical variables:
# <br><br>
# Please read the report file.

# %% [markdown]
# <hr>

# %% [markdown]
# ## 4. Quantitative Variables

# %% [markdown]
# Now, let’s analyze descriptive statics for quantitative variables. In this section we can find central tendency, dispersion, and shape measurements. Then we draw the distribution plot to compare with normal distribution.

# %%
def kde_plot(x):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    plt.figure(figsize = (8,3))
    sns.distplot(df[x], kde_kws={"lw": 5}, hist_kws = {'alpha': 0.25})
    sns.despine(left = True)
    
    mean = df[x].mean()
    median = df[x].median()
    
    plt.axvline(mean, color ='black', linestyle ='dashed')
    plt.axvline(median, color ='green', linestyle ='solid')
    plt.xlabel('')
    plt.ylabel('')
    
    return plt.show()

# %% [markdown]
# Now we can see the statistical interpretation for quantitative variables:

# %%
kde_plot('Area')
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
kde_plot('Frontage')
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
kde_plot('NearStation')
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
kde_plot('BuildingYear')
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
kde_plot('Price')
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <hr>

# %%
#minimum Area
df[df['Area'] == df['Area'].min()]
# Out:
#                                      Type   Municipality  NearStation  \
# 63    Residential Land(Land and Building)   Chiyoda Ward          2.0
# 370   Residential Land(Land and Building)      Chuo Ward          1.0
# 393   Residential Land(Land and Building)      Chuo Ward          2.0
# 394   Residential Land(Land and Building)      Chuo Ward          2.0
# 497   Residential Land(Land and Building)      Chuo Ward          2.0
# 236         1995.0       SRC           Office       West    Not yet
# 805         2001.0       SRC           Office       West    Not yet
# 825         1978.0        RC            House      North    Not yet
# 1200        1998.0         S           Office      North    Not yet
# 1328        1969.0        RC           Office       East    Not yet
# 2000        1977.0        RC           Office  Northeast    Not yet
# 2013        1961.0        RC        Warehouse  Southeast    Not yet
# 2141        2010.0         S           Office       West    Not yet
# 2402        2012.0        RC           Office       West    Not yet
# 2447        1971.0        RC            Other       West    Not yet
# 2634        1993.0       SRC  Housing Complex  Southwest    Not yet

# %% [markdown]
# <hr>

# %%
#minimum Frontage
df[df['Frontage'] == df['Frontage'].min()]
# Out:
#                                      Type   Municipality  NearStation  \
# 2354  Residential Land(Land and Building)  Shinjuku Ward          8.0
#
#         Price FloorPlan  Area         LandShape  Frontage  BuildingYear  \
# 2354  7600000        1K    40  Flag-shaped etc.       1.0        1948.0
#
#      Structure              Use Direction Renovation
# 2354         W  Housing Complex      East    Not yet

# %%
#maximum Frontage
df[df['Frontage'] == df['Frontage'].max()]
# Out:
#                                      Type   Municipality  NearStation  \
# 805   Residential Land(Land and Building)    Minato Ward          1.0
# 1200  Residential Land(Land and Building)    Minato Ward          3.0
# 2141  Residential Land(Land and Building)      Chuo Ward          7.0
# 2250  Residential Land(Land and Building)    Minato Ward          3.0
# 2251  Residential Land(Land and Building)  Shinjuku Ward          6.0
# 2402  Residential Land(Land and Building)  Shinjuku Ward          5.0
# 2447  Residential Land(Land and Building)  Shinjuku Ward          9.0
# 2634  Residential Land(Land and Building)    Minato Ward          4.0
#
#             Price FloorPlan  Area                LandShape  Frontage  \
# 805   30000000000        1K  2000         Irregular Shaped      50.0
# 1200   6600000000        1K  2000  Semi-rectangular Shaped      50.0
# 2141  14000000000        1K  2000              Semi-shaped      50.0
# 2250   2700000000        1K  1300  Semi-rectangular Shaped      50.0
# 2251   1900000000        1K  1400  Semi-rectangular Shaped      50.0
# 2402   3900000000        1K  2000              Semi-shaped      50.0
# 2447   4400000000        1K  2000         Irregular Shaped      50.0
# 2634  61000000000        1K  2000         Irregular Shaped      50.0
#
#       BuildingYear Structure              Use  Direction Renovation
# 805         2001.0       SRC           Office       West    Not yet
# 1200        1998.0         S           Office      North    Not yet
# 2141        2010.0         S           Office       West    Not yet
# 2250        1985.0       SRC           Office      South    Not yet
# 2251        1989.0        RC           Office      North    Not yet
# 2402        2012.0        RC           Office       West    Not yet
# 2447        1971.0        RC            Other       West    Not yet
# 2634        1993.0       SRC  Housing Complex  Southwest    Not yet

# %% [markdown]
# <hr>

# %%
#minimum NearStation
df[df['NearStation'] == df['NearStation'].min()].head(3)
# Out:
#                                     Type Municipality  NearStation  \
# 531  Residential Land(Land and Building)    Chuo Ward          0.0
# 662  Residential Land(Land and Building)    Chuo Ward          0.0
# 706  Residential Land(Land and Building)    Chuo Ward          0.0
#
#           Price FloorPlan  Area                LandShape  Frontage  \
# 531  3800000000        1K   390  Semi-rectangular Shaped      12.9
# 662   140000000        1K    50  Semi-rectangular Shaped       4.0
# 706  2500000000        1K   470         Irregular Shaped      13.0
#
#      BuildingYear Structure     Use  Direction Renovation
# 531        1994.0       SRC  Office  Southeast    Not yet
# 662        1988.0        RC   House  Southeast    Not yet
# 706        1976.0       SRC   House  Northwest    Not yet

# %%
#maximum NearStation
df[df['NearStation'] == df['NearStation'].max()].head(3)
# Out:
#                                      Type Municipality  NearStation  \
# 2758  Residential Land(Land and Building)  Minato Ward         16.0
#
#           Price FloorPlan  Area           LandShape  Frontage  BuildingYear  \
# 2758  110000000        1K    85  Semi-square Shaped       8.0        1995.0
#
#      Structure    Use  Direction Renovation
# 2758         W  House  Southwest    Not yet

# %% [markdown]
# <hr>

# %%
#minimum BuildingYear
df[df['BuildingYear'] == df['BuildingYear'].min()].head(3)
# Out:
#                                     Type  Municipality  NearStation  \
# 93   Residential Land(Land and Building)  Chiyoda Ward          1.0
# 94   Residential Land(Land and Building)  Chiyoda Ward          1.0
# 412  Residential Land(Land and Building)     Chuo Ward          1.0
#
#           Price FloorPlan  Area           LandShape  Frontage  BuildingYear  \
# 93     80000000        1K    55  Rectangular Shaped       6.0        1945.0
# 94    100000000        1K    55  Rectangular Shaped       6.0        1945.0
# 412  2400000000        1K   125  Semi-square Shaped      10.1        1945.0
#
#     Structure     Use  Direction Renovation
# 93         RC  Office      South    Not yet
# 94         RC    Shop      South    Not yet
# 412        RC    Shop  Northwest    Not yet

# %%
#maximum BuildingYear
df[df['BuildingYear'] == df['BuildingYear'].max()].head(3)
# Out:
#                                      Type   Municipality  NearStation  \
# 2460  Residential Land(Land and Building)  Shinjuku Ward          5.0
#
#          Price FloorPlan  Area         LandShape  Frontage  BuildingYear  \
# 2460  76000000        1K    75  Flag-shaped etc.       2.5        2020.0
#
#      Structure    Use Direction Renovation
# 2460         W  House     South    Not yet

# %% [markdown]
# <hr>

# %%
#minimum Price
df[df['Price'] == df['Price'].min()]
# Out:
#                                     Type Municipality  NearStation   Price  \
# 865  Residential Land(Land and Building)  Minato Ward          4.0  520000
#
#     FloorPlan  Area                LandShape  Frontage  BuildingYear  \
# 865        1K    45  Semi-rectangular Shaped       5.0        1979.0
#
#     Structure    Use Direction Renovation
# 865         S  House      East    Not yet

# %%
#maximum Price
df[df['Price'] == df['Price'].max()]
# Out:
#                                      Type Municipality  NearStation  \
# 2634  Residential Land(Land and Building)  Minato Ward          4.0
#
#             Price FloorPlan  Area         LandShape  Frontage  BuildingYear  \
# 2634  61000000000        1K  2000  Irregular Shaped      50.0        1993.0
#
#      Structure              Use  Direction Renovation
# 2634       SRC  Housing Complex  Southwest    Not yet

# %% [markdown]
# <hr>

# %% [markdown]
# ## 5. Handle Outliers

# %% [markdown]
# In the previous sections, we saw some variables have outliers, and before going further we should handle them. The big outliers are in “Price” and when we see statistical analysis of Price, we realize this variable in correlated Area. So, we can run feature engineering to handle price’s outlier. To begin with, I work on price and area. For doing this, I create a new feature as price per area:

# %%
df['Price_per_Area'] = df['Price'] / df['Area']
df.head(3)
# Out:
#                                   Type  Municipality  NearStation      Price  \
# 0  Residential Land(Land and Building)  Chiyoda Ward          2.0  400000000
# 1  Residential Land(Land and Building)  Chiyoda Ward          1.0  180000000
# 2  Residential Land(Land and Building)  Chiyoda Ward          4.0  120000000
#
#   FloorPlan  Area                LandShape  Frontage  BuildingYear Structure  \
# 0        1K   110       Trapezoidal Shaped       9.0        2018.0         S
# 1        1K    50       Rectangular Shaped       5.2        1976.0        RC
# 2        1K    65  Semi-rectangular Shaped       6.5        1970.0         S
#
#                Use  Direction Renovation  Price_per_Area
# 0           Office  Northwest    Not yet    3.636364e+06
# 1  Housing Complex  Southwest    Not yet    3.600000e+06
# 2            House      South    Not yet    1.846154e+06

# %% [markdown]
# now, let’s see the distribution shape of price_per_area

# %%
plt.figure(figsize = (8,3))
sns.distplot(df['Price_per_Area'], kde_kws={"lw": 5}, hist_kws = {'alpha': 0.25})
sns.despine(left = True)
    
mean = df['Price_per_Area'].mean()
median = df['Price_per_Area'].median()
    
plt.axvline(mean, color ='black', linestyle ='dashed')
plt.axvline(median, color ='green', linestyle ='solid')
plt.xlabel('')
plt.ylabel('')
    
plt.show()
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The shape shows it’s extremely right skewed and we have big outlier. So, for handling outlier, we cannot use z-score, because this variable does not stick to normal distribution. Instead, we use MAD (median absolute deviation) technique that is a very robust method for this condition. First of all, I searched on the internet and found the median price per square feet in Tokyo.

# %%
median_prices = {"Tokyo": 951000}

# %% [markdown]
# Now, I filter dataset (removing outlier) based on the MAD technique.

# %%
df.shape
# Out:
# (2761, 14)

# %%
#call province median from the dictionary
Median = median_prices["Tokyo"]
    
#difference between each price_per_area with the called median
df['Median_Diff'] = 0

for i in range(len(df)):
    median_diff = abs(df.loc[i , 'Price_per_Area'] - Median)
    df.at[i, 'Median_Diff'] = median_diff
    
#calculate the median of new column
MAD = df['Median_Diff'].median()
    
#determine treshold
threshold = MAD * 3
    
#detect and filter rows based on outlier
df = df[~(df['Median_Diff'] > threshold)]
    
#remove the differenece column
df = df.drop(['Median_Diff'], axis=1)

# %% [markdown]
# For the last time, let’s see the distribution of price.

# %%
plt.figure(figsize = (8,3))
sns.distplot(df['Price_per_Area'], kde_kws={"lw": 5}, hist_kws = {'alpha': 0.25})
sns.despine(left = True)
    
mean = df['Price_per_Area'].mean()
median = df['Price_per_Area'].median()
    
plt.axvline(mean, color ='black', linestyle ='dashed')
plt.axvline(median, color ='green', linestyle ='solid')
plt.xlabel('')
plt.ylabel('')
    
plt.show()
# Out:
# C:\Users\Mehrdad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df=df.drop(['Price_per_Area'], axis=1)

# %% [markdown]
# <hr>

# %% [markdown]
# # Check Point

# %%
import pickle
with open('Dataset/final_dataset.pickle', 'wb') as file:
    pickle.dump(df, file)
